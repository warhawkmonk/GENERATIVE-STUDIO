# %%
import requests

API_URL = "http://127.0.0.1:8080/generate-text"

prompt = "Write a short and helpful response about AI tools for developers."
response = requests.post(API_URL, json={"prompt": prompt}, timeout=60)

print(response.status_code)
print(response.json())
